# %% [markdown]
# ## 画三维图

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
import platform
print("python version: ", platform.python_version())
# 方法一，利用关键字

# 定义坐标轴
fig = plt.figure()
ax1 = plt.axes(projection='3d')
# ax = fig.add_subplot(111,projection='3d')  #这种方法也可以画多个子图
z = np.linspace(0, 13, 1000)
x = 5*np.sin(z)
y = 5*np.cos(z)
zd = 13*np.random.random(100)
xd = 5*np.sin(zd)
yd = 5*np.cos(zd)
ax1.scatter3D(xd, yd, zd, cmap='Blues')  # 绘制散点图
ax1.plot3D(x, y, z, 'gray')  # 绘制空间曲线
plt.show()


# 方法二，利用三维轴方法
# 定义图像和三维格式坐标轴
fig1 = plt.figure()
ax2 = Axes3D(fig1)
# 定义三维数据
xx = np.arange(-5, 5, 0.5)
yy = np.arange(-5, 5, 0.5)
X, Y = np.meshgrid(xx, yy)
Z = np.sin(X)+np.cos(Y)

# 作图
ax2.plot_surface(X, Y, Z, cmap='rainbow')
# ax3.contour(X,Y,Z, zdim='z',offset=-2，cmap='rainbow)   #等高线图，要设置offset，为Z的最小值
plt.show()

# %% [markdown]
# ### 获取高清矢量图
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
#方法三 画散点
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# 打开画图窗口1，在三维空间中绘图
fig3 = plt.figure(1)
# ax3 = fig.gca(projection='3d')
ax3 = plt.axes(projection='3d')
  
# 给出点（0，0，0）和（100，200，300）
x = [0, 0, 0, 10]
y = [0, 10, 0, 0]
z = [0, 0, 0, 0]
  

a = np.array([x[1], y[1], z[1]])
b = np.array([x[3], y[3], z[3]])
c = np.cross(a,b)

a1 = np.array([1,2,0])
b1 = np.array([1,0,0])
c1 = np.cross(a1, b1)
print("p1 %d %d %d" % (x[1], y[1], z[1]))
print("p3 %d %d %d" % (c[0], c[1], c[2]))
print("p3 %d %d %d" % (c1[0], c1[1], c1[2]))
x.append(0)
y.append(0)
z.append(0)
x.append(c[0])
y.append(c[1])
z.append(c[2])


# 将数组中的前两个点进行连线
ax3.plot(x, y, z, c='r')
ax3.scatter(x, y, z, c='g')

ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.set_zlabel('z')

# n=range(len(x))
# for i,txt in enumerate(n):
#     ax3.annotate(txt,(x[i],y[i], z[i]))
#     text(x[i], y[i], z[i],'\leftarrowsin(t) = .707','EdgeColor','red');
    
plt.show()
# Out:
# p1 0 10 0
# p3 0 0 -100
# p3 0 0 -2

# %%
def normalization(data):
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range


a1 = np.array([184,55,1])
b1 = np.array([132,452,1])
c1 = np.cross(a1, b1)
c2 = np.cross(b1, a1)

print("c1 %d %d %d" % (c1[0], c1[1], c1[2]))
print("c2 %d %d %d" % (c2[0], c2[1], c2[2]))

l3 = np.array([16,287,-18729])
l4 = np.array([3,388,-175772])
vx = np.cross(l3, l4)
print("vx     ",vx)

# l3_norm=normalization(l3)
# print(l3_norm)
l3_norm=l3/l3[2]
l4_norm=l4/l4[2]
# print(l3_norm, l4_norm)
vx_norm = np.cross(l3_norm, l4_norm)
print("vxnorm ",vx_norm)

vx=vx/vx[2]
vx_norm = vx_norm/vx_norm[2]
print(vx, vx_norm)

np.power(2,10)/np.power(3,10)
# Out:
# c1 -397 -52 75908
# c2 397 52 -75908
# vx      [-43179712   2756165      5347]
# vxnorm  [-1.31164243e-02  8.37222573e-04  1.62422391e-06]
# [-8.07550252e+03  5.15460071e+02  1.00000000e+00] [-8.07550252e+03  5.15460071e+02  1.00000000e+00]
# 0.017341529915832612

# %% [markdown]
# ## slam 3d 可视化
